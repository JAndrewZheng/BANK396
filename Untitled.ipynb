# %%
import argparse
import make_vid
import upload
import reddit

# %%
# !python make_vid.py
# Out:
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# 3.148
# 2.692
# 3.8440000000000003
# 3.172
# 3.004
# 2.164
# 2.212
# 2.86
# ...

# %%
# !python make_vid.py
# Out:
# Moviepy - Building video output.mp4.
# MoviePy - Writing audio in outputTEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video output.mp4
#
# Moviepy - Done !
# Moviepy - video ready output.mp4
# Moviepy - Building video final_outputREAL.mp4.
# MoviePy - Writing audio in temp-audio.m4a
# MoviePy - Done.
# Moviepy - Writing video final_outputREAL.mp4
#
# Moviepy - Done !
# Moviepy - video ready final_outputREAL.mp4
